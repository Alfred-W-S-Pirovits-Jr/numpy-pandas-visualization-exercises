# %%
from pydataset import data

# %%
# data('mpg', show_doc=True) # view the documentation for the dataset
mpg = data('mpg') # load the dataset and store it in a variable

# %% [markdown]
# # Part 1

# %% [markdown]
# Copy the code from the lesson to create a dataframe full of student grades.

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %% [markdown]
# Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
students_df = df.assign(passing_english = df.english >= 70)
students_df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True      75.666667
# 1      Jane    88       79       67             True      78.000000
# 2     Suzie    94       74       95             True      87.666667
# 3     Billy    98       96       88             True      94.000000
# 4       Ada    77       92       98             True      89.000000
# 5      John    79       76       93             True      82.666667
# 6    Thomas    82       64       81            False      75.666667
# 7     Marie    93       63       90            False      82.000000
# 8    Albert    92       62       87            False      80.333333
# 9   Richard    69       80       94             True      81.000000
# 10    Isaac    92       99       93             True      94.666667
# 11     Alan    92       62       72            False      75.333333

# %% [markdown]
# Sort the english grades by the passing_english column. How are duplicates handled? #duplicates default to alphebetical by index

# %%
students_df.sort_values(by='passing_english')
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 6    Thomas    82       64       81            False      75.666667
# 7     Marie    93       63       90            False      82.000000
# 8    Albert    92       62       87            False      80.333333
# 11     Alan    92       62       72            False      75.333333
# 0     Sally    62       85       80             True      75.666667
# 1      Jane    88       79       67             True      78.000000
# 2     Suzie    94       74       95             True      87.666667
# 3     Billy    98       96       88             True      94.000000
# 4       Ada    77       92       98             True      89.000000
# 5      John    79       76       93             True      82.666667
# 9   Richard    69       80       94             True      81.000000
# 10    Isaac    92       99       93             True      94.666667

# %% [markdown]
# Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
students_df.df.sort_values(['passing_english', 'name'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 students_df.df.sort_values(['passing_english', 'name'])
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'df'

# %%
students_df.sort_values(by='name').sort_values(by='passing_english')
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 11     Alan    92       62       72            False      75.333333
# 8    Albert    92       62       87            False      80.333333
# 7     Marie    93       63       90            False      82.000000
# 6    Thomas    82       64       81            False      75.666667
# 4       Ada    77       92       98             True      89.000000
# 3     Billy    98       96       88             True      94.000000
# 10    Isaac    92       99       93             True      94.666667
# 1      Jane    88       79       67             True      78.000000
# 5      John    79       76       93             True      82.666667
# 9   Richard    69       80       94             True      81.000000
# 0     Sally    62       85       80             True      75.666667
# 2     Suzie    94       74       95             True      87.666667

# %% [markdown]
# Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
students_df.sort_values(by='english').sort_values(by='passing_english')
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 8    Albert    92       62       87            False      80.333333
# 11     Alan    92       62       72            False      75.333333
# 7     Marie    93       63       90            False      82.000000
# 6    Thomas    82       64       81            False      75.666667
# 2     Suzie    94       74       95             True      87.666667
# 5      John    79       76       93             True      82.666667
# 1      Jane    88       79       67             True      78.000000
# 9   Richard    69       80       94             True      81.000000
# 0     Sally    62       85       80             True      75.666667
# 4       Ada    77       92       98             True      89.000000
# 3     Billy    98       96       88             True      94.000000
# 10    Isaac    92       99       93             True      94.666667

# %% [markdown]
# Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grad

# %%
students_df = df.assign(overall_grade = (df.math + df.english + df.reading)/3)
students_df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True      75.666667
# 1      Jane    88       79       67             True      78.000000
# 2     Suzie    94       74       95             True      87.666667
# 3     Billy    98       96       88             True      94.000000
# 4       Ada    77       92       98             True      89.000000
# 5      John    79       76       93             True      82.666667
# 6    Thomas    82       64       81            False      75.666667
# 7     Marie    93       63       90            False      82.000000
# 8    Albert    92       62       87            False      80.333333
# 9   Richard    69       80       94             True      81.000000
# 10    Isaac    92       99       93             True      94.666667
# 11     Alan    92       62       72            False      75.333333

# %%
Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
mpg_df = data('mpg')
mpg_df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
How many rows and columns are there?

# %%
mpg_df.shape
# Out:
# (234, 11)

# %%
mpg_df.size
# Out:
# 2574

# %%
What are the data types of each column?

# %%
Summarize the dataframe with .info and .describe

# %%
mpg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg_df.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# mpg.describe

# %%
Rename the cty column to city.

# %%
# df.rename(columns={'name': 'student'})
mpg_df = mpg_df.rename(columns={'cty': 'city'})

# %%
Rename the hwy column to highway.

# %%
mpg_df = mpg_df.rename(columns={'hwy': 'highway'})

# %%
Do any cars have better city mileage than highway mileage?

# %%
mpg_df[mpg_df['city'] > mpg_df['highway']] # NO
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class]
# Index: []

# %%
Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg_df = mpg_df.assign(mileage_difference = mpg_df.highway - mpg_df.city)
mpg_df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference
# ...

# %%
Which car (or cars) has the highest mileage difference?

# %%
mpg_df.sort_values(by='mileage_difference').tail()
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  city  highway  \
# 106        honda       civic    1.8  2008    4    auto(l5)   f    25       36
# 213   volkswagen       jetta    1.9  1999    4  manual(m5)   f    33       44
# 1           audi          a4    1.8  1999    4    auto(l5)   f    18       29
# 223   volkswagen  new beetle    1.9  1999    4    auto(l4)   f    29       41
# 107        honda       civic    1.8  2008    4    auto(l5)   f    24       36
#
#     fl       class  mileage_difference
# 106  r  subcompact                  11
# 213  d     compact                  11
# 1    p     compact                  11
# 223  d  subcompact                  12
# 107  c  subcompact                  12

# %%
Which compact class car has the lowest highway mileage? The best?

# %%
mpg_df.sort_values(by='mileage_difference').head()
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  city  \
# 204       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4    15
# 177       toyota        4runner 4wd    3.4  1999    6  manual(m5)   4    15
# 152       nissan     pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# 85          ford    f150 pickup 4wd    4.2  1999    6  manual(m5)   4    14
# 30     chevrolet    k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4    11
#
#      highway fl   class  mileage_difference
# 204       17  r  pickup                   2
# 177       17  r     suv                   2
# 152       17  r     suv                   2
# 85        17  r  pickup                   3
# 30        14  e     suv                   3

# %%
Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg_df =mpg_df.assign(average_mileage = (mpg_df.city + mpg_df.highway)/2)
mpg_df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
Which dodge car has the best average mileage? The worst?

# %%
mpg_df[mpg_df.manufacturer == 'dodge'].sort_values(by='average_mileage', ascending = False).head(1) #caravan 2wd
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  mileage_difference  average_mileage
# 38  r  minivan                   6             21.0

# %%
mpg_df[mpg_df.manufacturer == 'dodge'].sort_values(by='average_mileage', ascending = False).tail(1)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  mileage_difference  average_mileage
# 70       12  e  pickup                   3             10.5

# %% [markdown]
# # Part 3

# %%
Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
mammals_df = data('Mammals')
mammals_df
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
How many rows and columns are there?

# %%
mammals_df.shape
# Out:
# (107, 4)

# %%
What are the data types?

# %%
mammals_df.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
Summarize the dataframe with .info and .describe

# %%
mammals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
mammals_df.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
What is the the weight of the fastest animal?

# %%
mammals_df.sort_values(by='weight').sort_values(by='speed').tail(1).weight
# Out:
# 53    55.0
# Name: weight, dtype: float64

# %%
What is the overal percentage of specials?

# %%
mammals_df.specials.value_counts('False') #9.3458%
# Out:
# False    0.906542
# True     0.093458
# Name: specials, dtype: float64

# %%
How many animals are hoppers that are above the median speed? What percentage is this?

# %%
mammals_df.hoppers[mammals_df.speed > 48].value_counts() #7#7 above median speed
# Out:
# False    46
# True      7
# Name: hoppers, dtype: int64

# %%
mammals_df.hoppers[mammals_df.speed > 48].value_counts('True') # 13.2075
# Out:
# False    0.867925
# True     0.132075
# Name: hoppers, dtype: float64
