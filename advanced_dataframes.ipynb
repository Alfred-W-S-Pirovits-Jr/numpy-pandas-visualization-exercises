# %%
import numpy as np
import pandas as pd
from env import get_db_url

# %%
query = '''
SELECT *
FROM employees
LIMIT 200;

'''
employee_dept = pd.read_sql(query, get_db_url('employees'))
employee_dept.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %% [markdown]
# 5. a. Intentionally make a typo in the database url. What kind of error message do you see?

# %%
query = '''
SELECT *
FROM employees
LIMIT 200;

'''
employee_dept = pd.read_sql(query, get_db_url('employes')) #Traceback Error and access denied
employee_dept.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %% [markdown]
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
query = '''
SEECT *
FROM employes
LIMIT 200;

'''
employee_dept = pd.read_sql(query, get_db_url('employees'))
employee_dept.head()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /usr/local/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/pymysql/cursors.py:158, in Cursor.execute(self, query, args)
# ...

# %% [markdown]
# 6. Read the employees and titles tables into two separate DataFrames.

# %%
query = '''
SELECT *
FROM employees;

'''
employees_df = pd.read_sql(query, get_db_url('employees'))
employees_df.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
query = '''
SELECT *
FROM titles;

'''
titles_df = pd.read_sql(query, get_db_url('employees'))
titles_df.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees_df.shape #read (number_of_rows, number_of_columns)
# Out:
# (300024, 6)

# %%
titles_df.shape
# Out:
# (443308, 4)

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.

# %%
employees_df.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
titles_df.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %%
employees_df.nunique() #nope
# Out:
# emp_no        300024
# birth_date      4750
# first_name      1275
# last_name       1637
# gender             2
# hire_date       5434
# dtype: int64

# %%
titles_df['title'].nunique() #7 unique titles
# Out:
# 7

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %%
titles_df.sort_values(by='to_date').head() #1985-03-01
# Out:
#         emp_no            title   from_date     to_date
# 16064    20869         Engineer  1985-02-17  1985-03-01
# 406358  474918         Engineer  1985-02-10  1985-03-11
# 346216  434232            Staff  1985-02-26  1985-03-20
# 35527    34059  Senior Engineer  1985-02-10  1985-03-23
# 277603  287732            Staff  1985-04-14  1985-04-17

# %%
titles_df['to_date'].min() #same
# Out:
# datetime.date(1985, 3, 1)

# %% [markdown]
# 11. What is the most recent date in the to_date column?

# %%
titles_df['to_date'].max() #which means still working
# Out:
# datetime.date(9999, 1, 1)

# %% [markdown]
# #  Part # 2

# %% [markdown]
# 1.  Copy the users and roles DataFrames from the examples above.

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# 2.  What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on= 'id', how='left', indicator = True)
# Out:
#    id_x name_x  role_id  id_y    name_y     _merge
# 0     1    bob      1.0   1.0     admin       both
# 1     2    joe      2.0   2.0    author       both
# 2     3  sally      3.0   3.0  reviewer       both
# 3     4   adam      3.0   3.0  reviewer       both
# 4     5   jane      NaN   NaN       NaN  left_only
# 5     6   mike      NaN   NaN       NaN  left_only

# %% [markdown]
# It returns the appropriate information from roles discarding what is not needed

# %%
users.merge(roles, left_on='role_id', right_on= 'id', how='right', indicator = True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %% [markdown]
# It maintains the fidelity of the roles table and adds appropriate info from users.  It discards the rest of the lines from users.

# %% [markdown]
# 3.  What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on= 'id', how='outer', indicator = True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %% [markdown]
# It gives us the 7 possibilities, the first six from users and the left over 7th possibility from the commenter that is unmatched.  Since admin author and reviewer appears on the users table it does not return those from roles.

# %% [markdown]
# 4.  What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users.merge(roles, how='outer', indicator = True)
# Out:
#    id       name  role_id      _merge
# 0   1        bob      1.0   left_only
# 1   2        joe      2.0   left_only
# 2   3      sally      3.0   left_only
# 3   4       adam      3.0   left_only
# 4   5       jane      NaN   left_only
# 5   6       mike      NaN   left_only
# 6   1      admin      NaN  right_only
# 7   2     author      NaN  right_only
# 8   3   reviewer      NaN  right_only
# 9   4  commenter      NaN  right_only

# %% [markdown]
# It gives us the 9 total possibilities by combining the two tables.  since we are not joining on id and role_id respectively it gives us all the possibilities

# %% [markdown]
# 5.  Load the mpg dataset from PyDataset.

# %%
from pydataset import data
mpg_df = data('mpg')
mpg_df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# 6.  Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# 7.  How many rows and columns are in the dataset?

# %% [markdown]
# There are 234 rows and 11 columns.  alternatively I can use .shape

# %%
mpg_df.shape
# Out:
# (234, 11)

# %% [markdown]
# 8.  Check out your column names and perform any cleanup you may want on them.

# %%
mpg_df = mpg_df.rename(columns = {'displ': 'cylinders',
                        'cyl': 'cylinders',
                        'cty': 'city',
                        'hwy': 'highway',
                        'drv': 'drive',
                        'trans': 'transmission',
                        })
mpg_df
# Out:
#     manufacturer   model  cylinders  year  cylinders transmission drive  city  \
# 1           audi      a4        1.8  1999          4     auto(l5)     f    18
# 2           audi      a4        1.8  1999          4   manual(m5)     f    21
# 3           audi      a4        2.0  2008          4   manual(m6)     f    20
# 4           audi      a4        2.0  2008          4     auto(av)     f    21
# 5           audi      a4        2.8  1999          6     auto(l5)     f    16
# ..           ...     ...        ...   ...        ...          ...   ...   ...
# 230   volkswagen  passat        2.0  2008          4     auto(s6)     f    19
# 231   volkswagen  passat        2.0  2008          4   manual(m6)     f    21
# 232   volkswagen  passat        2.8  1999          6     auto(l5)     f    16
# 233   volkswagen  passat        2.8  1999          6   manual(m5)     f    18
# 234   volkswagen  passat        3.6  2008          6     auto(s6)     f    17
#
#      highway fl    class
# ...

# %% [markdown]
# 9.  Display the summary statistics for the dataset.

# %%
mpg_df.describe()
# Out:
#         cylinders         year   cylinders        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# 10.  How many different manufacturers are there?

# %%
mpg_df.value_counts('manufacturer').count()
# Out:
# 15

# %% [raw]
# There are 15 unique manufacturers

# %% [markdown]
# 11.  How many different models are there?

# %%
mpg_df.value_counts('model').count()
# Out:
# 38

# %% [markdown]
# 12.  Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg_df = mpg_df.assign(mileage_difference = mpg_df.highway - mpg_df.city)
mpg_df
# Out:
#     manufacturer   model  cylinders  year  cylinders transmission drive  city  \
# 1           audi      a4        1.8  1999          4     auto(l5)     f    18
# 2           audi      a4        1.8  1999          4   manual(m5)     f    21
# 3           audi      a4        2.0  2008          4   manual(m6)     f    20
# 4           audi      a4        2.0  2008          4     auto(av)     f    21
# 5           audi      a4        2.8  1999          6     auto(l5)     f    16
# ..           ...     ...        ...   ...        ...          ...   ...   ...
# 230   volkswagen  passat        2.0  2008          4     auto(s6)     f    19
# 231   volkswagen  passat        2.0  2008          4   manual(m6)     f    21
# 232   volkswagen  passat        2.8  1999          6     auto(l5)     f    16
# 233   volkswagen  passat        2.8  1999          6   manual(m5)     f    18
# 234   volkswagen  passat        3.6  2008          6     auto(s6)     f    17
#
# ...

# %% [markdown]
# 13.  Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg_df = mpg_df.assign(average_mileage = (mpg_df.city + mpg_df.highway)/2)
mpg_df
# Out:
#     manufacturer   model  cylinders  year  cylinders transmission drive  city  \
# 1           audi      a4        1.8  1999          4     auto(l5)     f    18
# 2           audi      a4        1.8  1999          4   manual(m5)     f    21
# 3           audi      a4        2.0  2008          4   manual(m6)     f    20
# 4           audi      a4        2.0  2008          4     auto(av)     f    21
# 5           audi      a4        2.8  1999          6     auto(l5)     f    16
# ..           ...     ...        ...   ...        ...          ...   ...   ...
# 230   volkswagen  passat        2.0  2008          4     auto(s6)     f    19
# 231   volkswagen  passat        2.0  2008          4   manual(m6)     f    21
# 232   volkswagen  passat        2.8  1999          6     auto(l5)     f    16
# 233   volkswagen  passat        2.8  1999          6   manual(m5)     f    18
# 234   volkswagen  passat        3.6  2008          6     auto(s6)     f    17
#
# ...

# %% [markdown]
# 14.  Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg_df = mpg_df.assign(is_automatic = mpg_df.transmission.str.contains('auto'))
mpg_df
# Out:
#     manufacturer   model  cylinders  year  cylinders transmission drive  city  \
# 1           audi      a4        1.8  1999          4     auto(l5)     f    18
# 2           audi      a4        1.8  1999          4   manual(m5)     f    21
# 3           audi      a4        2.0  2008          4   manual(m6)     f    20
# 4           audi      a4        2.0  2008          4     auto(av)     f    21
# 5           audi      a4        2.8  1999          6     auto(l5)     f    16
# ..           ...     ...        ...   ...        ...          ...   ...   ...
# 230   volkswagen  passat        2.0  2008          4     auto(s6)     f    19
# 231   volkswagen  passat        2.0  2008          4   manual(m6)     f    21
# 232   volkswagen  passat        2.8  1999          6     auto(l5)     f    16
# 233   volkswagen  passat        2.8  1999          6   manual(m5)     f    18
# 234   volkswagen  passat        3.6  2008          6     auto(s6)     f    17
#
# ...

# %% [markdown]
# 15.  Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg_df.groupby(['manufacturer']).average_mileage.describe().sort_values(by='mean', ascending=False).head(1)  #try to figure out how to isolate the max mean
# Out:
#               count  mean       std   min   25%   50%   75%   max
# manufacturer
# honda           9.0  28.5  1.984313  25.0  28.0  28.5  30.0  30.5

# %% [markdown]
# 16.  Do automatic or manual cars have better miles per gallon?

# %%
mpg_df.groupby('is_automatic').average_mileage.describe().sort_values(by='mean', ascending=False).head(1)
# Out:
#               count       mean       std   min   25%   50%   75%   max
# is_automatic
# False          77.0  22.227273  5.160927  10.5  19.5  22.0  25.0  39.5

# %% [markdown]
# Generally manual transmissions have better gas mileage by quartiles max mean etc.  it seems at best in the min there may be some overlap.  Further analysis is needed.

# %% [markdown]
# # Part 3

# %% [markdown]
# 1.  Use your get_db_url function to help you explore the data from the chipotle database.

# %%
chipotle_df = pd.read_sql('SELECT * FROM orders;', get_db_url('chipotle'))
chipotle_df
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
data('chipotle', show_doc=True)
# Out:
# Did you mean:
# Chile, Chirot, Cowles, hirose, cities, Hitters, shuttle, pottery, Pottery, alcohol, coleman

# %% [markdown]
# 2.  What is the total price for each order?

# %%
chipotle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
chipotle_df.item_price.str.strip('$').astype('float')
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
total_price_df = chipotle_df.assign(total_price = (chipotle_df.quantity * chipotle_df.item_price.str.strip('$').astype('float')))

# %%
total_price_df #in new appended column
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %% [markdown]
# 3.  What are the most popular 3 items?

# %%
total_price_df.item_name.value_counts().head(3)
# Out:
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Name: item_name, dtype: int64

# %%
chipotle_df.groupby('item_name').quantity.sum().sort_values(ascending=False).head(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %% [markdown]
# 4.  Which item has produced the most revenue?

# %%
total_pivot = total_price_df.pivot_table(index='item_name', columns='quantity', values = 'total_price', aggfunc = 'sum', margins = True)
total_pivot
# Out:
# quantity                                      1        2        3       4  \
# item_name
# 6 Pack Soft Drink                        343.97    25.96      NaN     NaN
# Barbacoa Bowl                            672.36      NaN      NaN     NaN
# Barbacoa Burrito                         894.75      NaN      NaN     NaN
# Barbacoa Crispy Tacos                    101.71    37.00      NaN     NaN
# Barbacoa Salad Bowl                      106.40      NaN      NaN     NaN
# Barbacoa Soft Tacos                      250.46      NaN      NaN     NaN
# Bottled Water                            199.48    67.08    73.62   48.00
# Bowl                                       7.40      NaN    66.60     NaN
# Burrito                                   44.40      NaN      NaN     NaN
# Canned Soda                               91.56    82.84      NaN   17.44
# Canned Soft Drink                        330.00   135.00    78.75   60.00
# ...

# %%
total_pivot[total_pivot.All > 1000]#.sort_values(by='All')
# Out:
# quantity                             1        2        3       4     5     7  \
# item_name
# Chicken Bowl                   6700.02  1167.04   177.57     NaN   NaN   NaN
# Chicken Burrito                4957.08   992.48   157.50  280.00   NaN   NaN
# Chicken Salad Bowl              951.25   555.00      NaN     NaN   NaN   NaN
# Chicken Soft Tacos             1017.17   181.84      NaN     NaN   NaN   NaN
# Chips and Fresh Tomato Salsa    287.61    35.40      NaN   47.20   NaN   NaN
# Chips and Guacamole            1975.41   388.96    40.05   71.20   NaN   NaN
# Steak Bowl                     2066.64   334.96    78.21     NaN   NaN   NaN
# Steak Burrito                  3522.23   547.40   166.50     NaN   NaN   NaN
# Veggie Burrito                  901.02      NaN   101.25     NaN   NaN   NaN
# All                           31251.05  5305.84  1123.38  523.84  37.5  73.5
#
# quantity                           8     10      15       All
# item_name
# ...

# %%
total_pivot.All.values[:-1].max()
# Out:
# 8044.63

# %%
pd.crosstab(total_price_df.item_name, total_price_df.total_price, margins=True) #Deadend but think about it later
# Out:
# total_price                            1.09  1.25  1.5  1.69  1.99  2.15  \
# item_name
# 6 Pack Soft Drink                         0     0    0     0     0     0
# Barbacoa Bowl                             0     0    0     0     0     0
# Barbacoa Burrito                          0     0    0     0     0     0
# Barbacoa Crispy Tacos                     0     0    0     0     0     0
# Barbacoa Salad Bowl                       0     0    0     0     0     0
# Barbacoa Soft Tacos                       0     0    0     0     0     0
# Bottled Water                            22     0  117     0     0     0
# Bowl                                      0     0    0     0     0     0
# Burrito                                   0     0    0     0     0     0
# Canned Soda                              84     0    0     0     0     0
# Canned Soft Drink                         0   264    0     0     0     0
# Carnitas Bowl                             0     0    0     0     0     0
# ...

# %%
total_price_df.item_name.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object>

# %% [markdown]
# 5.  Join the employees and titles DataFrames together.

# %%
#left_df.merge(right_df, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, indicator=False)
merged_table = employees_df.merge(titles_df, left_on='emp_no', right_on='emp_no', how='outer')
merged_table
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %% [markdown]
# 6.  For each title, find the hire date of the employee that was hired most recently with that title.

# %%
merged_table.groupby('title').hire_date.agg('max')
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %% [markdown]
# 7.  Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
pd.crosstab(merged_table.title, merged_table.department)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[230], line 1
# ----> 1 pd.crosstab(merged_table.title, merged_table.department)
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'department'
